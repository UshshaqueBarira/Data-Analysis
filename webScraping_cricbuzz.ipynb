# %%
pip install Beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
import pandas as pd
import time
from bs4 import BeautifulSoup
import requests

# %%
try:
    page=requests.get("https://www.cricbuzz.com/")
    
except Exception as e:
    error_type,error_info, error_obj=sys.exc_info()
    print('error for',url)
    
time.sleep(2)
soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('div',attrs={'class':'cb-nws-intr'})

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
for i in links:
    print(i.text)
    print("\n")
# Out:
# Overton, Anderson take three each as India fold for 78 in the first innings after opting to bat
#
#
# England's likely No. 3 batsman is banking on his experience to compensate for his lack of red-ball cricket coming into the Leeds Test
#
#
# There was much to recommend The Hundred as a tournament in its own right. But it also shone a light on cricket's lack of a practical centre or a moral core, in turn raising a question on the direction the game's heading in
#
#
# The pacer picked his maiden ten-wicket haul to carry Pakistan to an easy win
#
#
# The Australian pacer pulled out to spend time with his family after a hectic season
#
#
# Pakistan's head coach will quarantine in Jamaica for 10 days and will not return with the rest of the team
#
#
# The New Zealand batsman has been quarantined at the team's hotel and has been experiencing moderate symptoms
#
#
# ...

# %%
try:
    page_medium=requests.get("https://medium.com/topic/popular")
    
except Exception as e:
    error_type,error_info, error_obj=sys.exc_info()
    print('error for',url)
    
time.sleep(2)
soup_medium=BeautifulSoup(page_medium.text,'html.parser')
links_medium=soup_medium.find_all('div',attrs={'class':'gq gr'})

# %%
page_medium
# Out:
# <Response [200]>

# %%
links_medium
# Out:
# []

# %%
for i in links_medium:
    print(i.text)
    print("\n")
